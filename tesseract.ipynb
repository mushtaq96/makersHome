# %%
def pdf_to_png(pdf_path, output_folder):
    base_name = os.path.splitext(os.path.basename(pdf_path))[0]  # Get the base name without extension
    output_path = os.path.join(output_folder, f"{base_name}.png")

    try:
        pdf_document = fitz.open(pdf_path)
        page = pdf_document[0]  # Assuming we're only processing the first page
        pix = page.get_pixmap(dpi=300)  # Adjust DPI for image quality
        pix.save(output_path)
        pdf_document.close()
        print(f"Saved PNG image to: {output_path}")
    except Exception as e:
        print(f"Error processing {pdf_path}: {e}")

# %%
import fitz  # PyMuPDF
from PIL import Image
import os

pdfs = '../Hackathon'  # Ensure this is set correctly
output_folder = "./pdf_images"  # Directory to save PNG images

subfolders = ['09_Wände'] #'01_Pfetten', '02_Binder', '03_Riegel', '06_Rippenplatten', '07_Unterzüge', '08_Stützen', '09_Wände', '10_Sandwich-Wände', '11_Vorgehängte', '13_Sandwich-Wände', '14_Treppen', '15_Podeste']

for item in subfolders:
    input_folder = os.path.join(pdfs, item)
    if not os.path.exists(input_folder):
        raise FileNotFoundError(f"Input folder does not exist: {input_folder}")
    
    # Process PDFs in this folder
    output_subfolder = os.path.join(output_folder, item)
    os.makedirs(output_subfolder, exist_ok=True)  # Create subfolder if it doesn't exist
    
    for pdf in os.listdir(input_folder):
        if not pdf.lower().endswith('.pdf'):
            continue
        
        try:
            pdf_path = os.path.join(input_folder, pdf)
            pdf_to_png(pdf_path, output_subfolder)
        except Exception as e:
            print(f"Error processing {pdf}: {e}")

print("Processing complete.")
# Out:
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-017_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-111_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-241_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-037_-_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-002_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-115_D_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-024_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-240_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-022_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-156_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-124_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-243_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-035_-_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-129_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-126_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-112_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-003_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-026_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-237_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-036_-_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-149_d_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-006_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-025_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-250_A_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-246_A_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-031_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-128_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-233_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-228_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-029_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-028_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-148_B_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-225_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-239_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-016_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-001_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-139_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-157_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-143_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-242_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-251_A_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-238_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-133_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-013_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-021_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-144_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-019_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-132_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-145_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-236_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-141_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-032_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-150_A_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-245_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-015_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-205_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-123_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-142_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-018_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-248_A_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-147_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-116_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-034_-_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-023_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-122_d_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-244_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-012_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-020_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-235_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-231_B_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-005_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-134_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-204_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-232_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-004_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-215_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-127_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-159_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-014_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-131_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-033_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-130_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-146_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-140_b_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-030_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-158_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-249_A_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-234_c_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-229_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-230_d_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-247_B_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-011_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-125_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-027_a_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-102_e_F.png
# Saved PNG image to: ./pdf_images/09_Wände/FT_XX_09-218_A_F.png
# Processing complete.

# %%
#convert to grayscale
image_path = './pdf_images/09_Wände/FT_XX_09-001_a_F.png'
output_folder = "./pdf_images_grayscale"
os.makedirs(output_folder, exist_ok=True)
def convert_to_grayscale(image_path):
    image = Image.open(image_path).convert("L")
    output_path = os.path.join(output_folder, 'FT_XX_09-001_a_F.png')
    image.save(output_path)
    print(f"Converted {image_path} to grayscale")
convert_to_grayscale(image_path)
# Out:
# Converted ./pdf_images/09_Wände/FT_XX_09-001_a_F.png to grayscale

# %%
import mupdf

def show_stext(document):
    '''
    Shows all available information about Stext blocks, lines and characters.
    '''
    for p in range(document.count_pages()):
        page = document.load_page(p)
        stextpage = mupdf.StextPage(page, mupdf.StextOptions())
        for block in stextpage:
            block_ = block.m_internal
            log(f'block: type={block_.type} bbox={block_.bbox}')
            for line in block:
                line_ = line.m_internal
                log(f'    line: wmode={line_.wmode}'
                        + f' dir={line_.dir}'
                        + f' bbox={line_.bbox}'
                        )
                for char in line:
                    char_ = char.m_internal
                    log(f'        char: {chr(char_.c)!r} c={char_.c:4} color={char_.color}'
                            + f' origin={char_.origin}'
                            + f' quad={char_.quad}'
                            + f' size={char_.size:6.2f}'
                            + f' font=('
                                +  f'is_mono={char_.font.flags.is_mono}'
                                + f' is_bold={char_.font.flags.is_bold}'
                                + f' is_italic={char_.font.flags.is_italic}'
                                + f' ft_substitute={char_.font.flags.ft_substitute}'
                                + f' ft_stretch={char_.font.flags.ft_stretch}'
                                + f' fake_bold={char_.font.flags.fake_bold}'
                                + f' fake_italic={char_.font.flags.fake_italic}'
                                + f' has_opentype={char_.font.flags.has_opentype}'
                                + f' invalid_bbox={char_.font.flags.invalid_bbox}'
                                + f' name={char_.font.name}'
                                + f')'
                            )

sample = '../Hackathon/09_Wände/FT_XX_09-001_a_F.pdf'
document = mupdf.fz  #Document(sample)
show_stext(document)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 40
#      21                     log(f'        char: {chr(char_.c)!r} c={char_.c:4} color={char_.color}'
#      22                             + f' origin={char_.origin}'
#      23                             + f' quad={char_.quad}'
#    (...)
#      36                                 + f')'
#      37                             )
#      39 sample = '../Hackathon/09_Wände/FT_XX_09-001_a_F.pdf'
# ---> 40 document = mupdf.Document(sample)
#      41 show_stext(document)
#
# AttributeError: module 'mupdf' has no attribute 'Document'

# %%
import cv2
img_path = './pdf_images_grayscale/FT_XX_09-001_a_F.png'
init_img = cv2.imread(img_path, 0)
[init_row, init_col] = init_img.shape # get the dimensions of the image (row, col, channels)
print(init_row, init_col)
# Out:
# 7016 9934

# %%
from img2table.document import Image
from img2table.ocr import TesseractOCR

# Load the image
image = Image(src=img_path)

# Initialize OCR
ocr = TesseractOCR(lang="deu")

# Extract tables
tables = image.extract_tables(ocr=ocr, min_confidence=90)
# Out:
# tesseract 4.1.1
#  leptonica-1.82.0
#   libgif 5.1.9 : libjpeg 8d (libjpeg-turbo 2.1.1) : libpng 1.6.37 : libtiff 4.3.0 : zlib 1.2.11 : libwebp 1.2.2 : libopenjp2 2.4.0
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.6.0 zlib/1.2.11 liblzma/5.2.5 bz2lib/1.0.8 liblz4/1.9.3 libzstd/1.4.8

# %%
import pandas as pd

# Process the extracted tables
for table in tables:
    print(table.content)
    # print(table.content[0][0])
    # print(table.bbox)
    print(table)

    # break
# Out:
# OrderedDict([(0, [TableCell(bbox=BBox(x1=8003, y1=1206, x2=8145, y2=1266), value='Pos'), TableCell(bbox=BBox(x1=8145, y1=1206, x2=8224, y2=1266), value='Stck'), TableCell(bbox=BBox(x1=8224, y1=1206, x2=9714, y2=1266), value='Bezeichnung')]), (1, [TableCell(bbox=BBox(x1=8003, y1=1266, x2=8145, y2=1325), value='1209'), TableCell(bbox=BBox(x1=8145, y1=1266, x2=8224, y2=1325), value=None), TableCell(bbox=BBox(x1=8224, y1=1266, x2=9714, y2=1325), value='Kugelkopf-Stabanker Zulagebewehrung nach Herstellerangaben')]), (2, [TableCell(bbox=BBox(x1=8003, y1=1325, x2=8145, y2=1384), value='2024'), TableCell(bbox=BBox(x1=8145, y1=1325, x2=8224, y2=1384), value=None), TableCell(bbox=BBox(x1=8224, y1=1325, x2=9714, y2=1384), value='Ankerschiene 38/17 L=15cm verzinkt')]), (3, [TableCell(bbox=BBox(x1=8003, y1=1384, x2=8145, y2=1443), value='4062'), TableCell(bbox=BBox(x1=8145, y1=1384, x2=8224, y2=1443), value=None), TableCell(bbox=BBox(x1=8224, y1=1384, x2=9714, y2=1443), value='Philipp Power Duo-Schiene h=70mm, L=1.25m')]), (4, [TableCell(bbox=BBox(x1=8003, y1=1443, x2=8145, y2=1502), value='5003-20'), TableCell(bbox=BBox(x1=8145, y1=1443, x2=8224, y2=1502), value=None), TableCell(bbox=BBox(x1=8224, y1=1443, x2=9714, y2=1502), value='L=20cm')])])
# ExtractedTable(title=None, bbox=(8003, 1206, 9714, 1502),shape=(5, 3))
# OrderedDict([(0, [TableCell(bbox=BBox(x1=7925, y1=1837, x2=9815, y2=1924), value='TAB 1. Mindestwerte der Biegerollendurchmesser bei Biegen (DIN EN 1992-1-1/NA, Tabelle'), TableCell(bbox=BBox(x1=7925, y1=1837, x2=9815, y2=1924), value='TAB 1. Mindestwerte der Biegerollendurchmesser bei Biegen (DIN EN 1992-1-1/NA, Tabelle'), TableCell(bbox=BBox(x1=7925, y1=1837, x2=9815, y2=1924), value='TAB 1. Mindestwerte der Biegerollendurchmesser bei Biegen (DIN EN 1992-1-1/NA, Tabelle'), TableCell(bbox=BBox(x1=7925, y1=1837, x2=9815, y2=1924), value='TAB 1. Mindestwerte der Biegerollendurchmesser bei Biegen (DIN EN 1992-1-1/NA, Tabelle'), TableCell(bbox=BBox(x1=7925, y1=1837, x2=9815, y2=1924), value='TAB 1. Mindestwerte der Biegerollendurchmesser bei Biegen (DIN EN 1992-1-1/NA, Tabelle'), TableCell(bbox=BBox(x1=7925, y1=1837, x2=9815, y2=1924), value='TAB 1. Mindestwerte der Biegerollendurchmesser bei Biegen (DIN EN 1992-1-1/NA, Tabelle')]), (1, [TableCell(bbox=BBox(x1=7925, y1=1924, x2=8738, y2=2378), value='D'), TableCell(bbox=BBox(x1=8738, y1=1924, x2=9165, y2=2064), value='Haken, Winkelhaken\nSchlaufen, Bügel (D\nmin'), TableCell(bbox=BBox(x1=8738, y1=1924, x2=9165, y2=2064), value='Haken, Winkelhaken\nSchlaufen, Bügel (D\nmin'), TableCell(bbox=BBox(x1=9165, y1=1924, x2=9815, y2=2064), value='Schrägstäbe oder andere\ngebogene Stäbe'), TableCell(bbox=BBox(x1=9165, y1=1924, x2=9815, y2=2064), value='Schrägstäbe oder andere\ngebogene Stäbe'), TableCell(bbox=BBox(x1=9165, y1=1924, x2=9815, y2=2064), value='Schrägstäbe oder andere\ngebogene Stäbe')]), (2, [TableCell(bbox=BBox(x1=7925, y1=1924, x2=8738, y2=2378), value='D'), TableCell(bbox=BBox(x1=8738, y1=2064, x2=9165, y2=2195), value='Stabdurchmesser ds'), TableCell(bbox=BBox(x1=8738, y1=2064, x2=9165, y2=2195), value='Stabdurchmesser ds'), TableCell(bbox=BBox(x1=9165, y1=2064, x2=9815, y2=2195), value='Mindestwerte der Betondeckung\nrechtwinklig zur Biegeebene'), TableCell(bbox=BBox(x1=9165, y1=2064, x2=9815, y2=2195), value='Mindestwerte der Betondeckung\nrechtwinklig zur Biegeebene'), TableCell(bbox=BBox(x1=9165, y1=2064, x2=9815, y2=2195), value='Mindestwerte der Betondeckung\nrechtwinklig zur Biegeebene')]), (3, [TableCell(bbox=BBox(x1=7925, y1=1924, x2=8738, y2=2378), value='D'), TableCell(bbox=BBox(x1=8738, y1=2195, x2=8951, y2=2378), value=None), TableCell(bbox=BBox(x1=8951, y1=2195, x2=9165, y2=2378), value=None), TableCell(bbox=BBox(x1=9165, y1=2195, x2=9379, y2=2378), value=None), TableCell(bbox=BBox(x1=9379, y1=2195, x2=9590, y2=2378), value=None), TableCell(bbox=BBox(x1=9590, y1=2195, x2=9815, y2=2378), value=None)]), (4, [TableCell(bbox=BBox(x1=7925, y1=2378, x2=9815, y2=6960), value='TAB 2. Mindestwerte der Biegerollendurchmesser d, für nach dem Schweißen gebogene Bewehrung\nbei einmaligen Biegen (DIN EN 1992-1-1/NA, Tabelle\nD\nSchweißung auf der\nSchweißung auf der\nSchweißung außerhalb\nSchweißung innerhalb\nAußenseite\nInnenseite\ndes Biegebereiches\ndes Biegebereiches\nder Biegung\nder Biegung\nds\n500 ds\nS-Haken\n- bei Rundstahl\nbei Rundstahl\nBETONDECKUNG\nbei Baustahlgewebe\n(senkrechte Stäbe\n(senkrechte Stäbe innen)\n(Längsstab)\n(\nBügel)\nAbstandhalter\nVerlegemaß\nBAUSTOFFE\nBetondeckung\nBeton Festigkeitsklasse\nBetonstahl\nNennmaß (mm)\nFeuchtigkeitsklasse\nBSt\nBSt\n(A\nBauteil\n(A\noben\nWO WF WS\nunten\nBEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstabstahl - Positionen\nD\nnach DIN EN 1992-1-1/NA, Tabelle NA.8.1DEa\nmin\nBetonstahlmatten - Positionen\nAlle Maße und Schnittlängen sind vor der Ausführung zu prüfen\nOBERFLACHEN\nSichtbeton glatt\nEinfüllseite\nSonderstruktur\nAlle\nKanten\nfasen\n3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPo ...
# ExtractedTable(title=None, bbox=(7925, 1837, 9815, 6960),shape=(5, 6))
# OrderedDict([(0, [TableCell(bbox=BBox(x1=7925, y1=2512, x2=9815, y2=2660), value='TAB 2. Mindestwerte der Biegerollendurchmesser d, für nach dem Schweißen gebogene Bewehrung\nbei einmaligen Biegen (DIN EN 1992-1-1/NA, Tabelle'), TableCell(bbox=BBox(x1=7925, y1=2512, x2=9815, y2=2660), value='TAB 2. Mindestwerte der Biegerollendurchmesser d, für nach dem Schweißen gebogene Bewehrung\nbei einmaligen Biegen (DIN EN 1992-1-1/NA, Tabelle'), TableCell(bbox=BBox(x1=7925, y1=2512, x2=9815, y2=2660), value='TAB 2. Mindestwerte der Biegerollendurchmesser d, für nach dem Schweißen gebogene Bewehrung\nbei einmaligen Biegen (DIN EN 1992-1-1/NA, Tabelle'), TableCell(bbox=BBox(x1=7925, y1=2512, x2=9815, y2=2660), value='TAB 2. Mindestwerte der Biegerollendurchmesser d, für nach dem Schweißen gebogene Bewehrung\nbei einmaligen Biegen (DIN EN 1992-1-1/NA, Tabelle'), TableCell(bbox=BBox(x1=7925, y1=2512, x2=9815, y2=2660), value='TAB 2. Mindestwerte der Biegerollendurchmesser d, für nach dem Schweißen gebogene Bewehrung\nbei einmaligen Biegen (DIN EN 1992-1-1/NA, Tabelle')]), (1, [TableCell(bbox=BBox(x1=7925, y1=2660, x2=8421, y2=2928), value='D'), TableCell(bbox=BBox(x1=8421, y1=2660, x2=9118, y2=2730), value=None), TableCell(bbox=BBox(x1=8421, y1=2660, x2=9118, y2=2730), value=None), TableCell(bbox=BBox(x1=9118, y1=2660, x2=9815, y2=2730), value=None), TableCell(bbox=BBox(x1=9118, y1=2660, x2=9815, y2=2730), value=None)]), (2, [TableCell(bbox=BBox(x1=7925, y1=2660, x2=8421, y2=2928), value='D'), TableCell(bbox=BBox(x1=8421, y1=2730, x2=8769, y2=2928), value='Schweißung außerhalb\ndes Biegebereiches'), TableCell(bbox=BBox(x1=8769, y1=2730, x2=9118, y2=2928), value='Schweißung innerhalb\ndes Biegebereiches'), TableCell(bbox=BBox(x1=9118, y1=2730, x2=9466, y2=2928), value='Schweißung auf der\nAußenseite\nder Biegung'), TableCell(bbox=BBox(x1=9466, y1=2730, x2=9815, y2=2928), value='Schweißung auf der\nInnenseite\nder Biegung')]), (3, [TableCell(bbox=BBox(x1=7925, y1=2928, x2=8421, y2=3028), value=None), TableCell(bbox=BBox(x1=8421, y1=2928, x2=8769, y2=3028), value='ds'), TableCell(bbox=BBox(x1=8769, y1=2928, x2=9118, y2=3130), value=None), TableCell(bbox=BBox(x1=9118, y1=2928, x2=9466, y2=3130), value=None), TableCell(bbox=BBox(x1=9466, y1=2928, x2=9815, y2=3130), value='500 ds')]), (4, [TableCell(bbox=BBox(x1=7925, y1=3028, x2=8421, y2=3130), value=None), TableCell(bbox=BBox(x1=8421, y1=3028, x2=8769, y2=3130), value=None), TableCell(bbox=BBox(x1=8769, y1=2928, x2=9118, y2=3130), value=None), TableCell(bbox=BBox(x1=9118, y1=2928, x2=9466, y2=3130), value=None), TableCell(bbox=BBox(x1=9466, y1=2928, x2=9815, y2=3130), value='500 ds')])])
# ExtractedTable(title=None, bbox=(7925, 2512, 9815, 3130),shape=(5, 5))
# OrderedDict([(0, [TableCell(bbox=BBox(x1=5993, y1=3103, x2=6686, y2=3177), value='Mattensummenliste'), TableCell(bbox=BBox(x1=5993, y1=3103, x2=6686, y2=3177), value='Mattensummenliste'), TableCell(bbox=BBox(x1=5993, y1=3103, x2=6686, y2=3177), value='Mattensummenliste'), TableCell(bbox=BBox(x1=5993, y1=3103, x2=6686, y2=3177), value='Mattensummenliste'), TableCell(bbox=BBox(x1=5993, y1=3103, x2=6686, y2=3177), value='Mattensummenliste'), TableCell(bbox=BBox(x1=6686, y1=3103, x2=7636, y2=3177), value=None), TableCell(bbox=BBox(x1=6686, y1=3103, x2=7636, y2=3177), value=None), TableCell(bbox=BBox(x1=6686, y1=3103, x2=7636, y2=3177), value=None), TableCell(bbox=BBox(x1=6686, y1=3103, x2=7636, y2=3177), value=None), TableCell(bbox=BBox(x1=6686, y1=3103, x2=7636, y2=3177), value=None)]), (1, [TableCell(bbox=BBox(x1=5993, y1=3177, x2=6107, y2=3236), value='Pos.'), TableCell(bbox=BBox(x1=6107, y1=3177, x2=6221, y2=3236), value='Anz.'), TableCell(bbox=BBox(x1=6221, y1=3177, x2=6396, y2=3236), value='Bez/Typ'), TableCell(bbox=BBox(x1=6396, y1=3177, x2=6551, y2=3236), value='Breite'), TableCell(bbox=BBox(x1=6551, y1=3177, x2=6686, y2=3236), value='Länge'), TableCell(bbox=BBox(x1=6686, y1=3177, x2=6830, y2=3236), value='Pos.'), TableCell(bbox=BBox(x1=6830, y1=3177, x2=6975, y2=3236), value='Anz.'), TableCell(bbox=BBox(x1=6975, y1=3177, x2=7141, y2=3236), value=None), TableCell(bbox=BBox(x1=7141, y1=3177, x2=7389, y2=3236), value='Länge'), TableCell(bbox=BBox(x1=7389, y1=3177, x2=7636, y2=3236), value='Bem')]), (2, [TableCell(bbox=BBox(x1=5993, y1=3236, x2=6107, y2=3295), value=None), TableCell(bbox=BBox(x1=6107, y1=3236, x2=6221, y2=3295), value=None), TableCell(bbox=BBox(x1=6221, y1=3236, x2=6396, y2=3295), value=None), TableCell(bbox=BBox(x1=6396, y1=3236, x2=6551, y2=3295), value=None), TableCell(bbox=BBox(x1=6551, y1=3236, x2=6686, y2=3295), value=None), TableCell(bbox=BBox(x1=6686, y1=3236, x2=6830, y2=3295), value=None), TableCell(bbox=BBox(x1=6830, y1=3236, x2=6975, y2=3295), value=None), TableCell(bbox=BBox(x1=6975, y1=3236, x2=7141, y2=3295), value='20'), TableCell(bbox=BBox(x1=7141, y1=3236, x2=7389, y2=3295), value='0.35'), TableCell(bbox=BBox(x1=7389, y1=3236, x2=7636, y2=3295), value=None)]), (3, [TableCell(bbox=BBox(x1=5993, y1=3295, x2=6107, y2=3354), value=None), TableCell(bbox=BBox(x1=6107, y1=3295, x2=6221, y2=3354), value=None), TableCell(bbox=BBox(x1=6221, y1=3295, x2=6396, y2=3354), value='Q335A'), TableCell(bbox=BBox(x1=6396, y1=3295, x2=6551, y2=3354), value='2.30'), TableCell(bbox=BBox(x1=6551, y1=3295, x2=6686, y2=3354), value='2.93'), TableCell(bbox=BBox(x1=6686, y1=3295, x2=6830, y2=3354), value='2'), TableCell(bbox=BBox(x1=6830, y1=3295, x2=6975, y2=3354), value=None), TableCell(bbox=BBox(x1=6975, y1=3295, x2=7141, y2=3354), value='12'), TableCell(bbox=BBox(x1=7141, y1=3295, x2=7389, y2=3354), value='6.46'), TableCell(bbox=BBox(x1=7389, y1=3295, x2=7636, y2=3354), value=None)]), (4, [TableCell(bbox=BBox(x1=5993, y1=3354, x2=6107, y2=3416), value=None), TableCell(bbox=BBox(x1=6107, y1=3354, x2=6221, y2=3416), value='2'), TableCell(bbox=BBox(x1=6221, y1=3354, x2=6396, y2=3416), value=None), TableCell(bbox=BBox(x1=6396, y1=3354, x2=6551, y2=3416), value='0.85'), TableCell(bbox=BBox(x1=6551, y1=3354, x2=6686, y2=3416), value='2.93'), TableCell(bbox=BBox(x1=6686, y1=3354, x2=6830, y2=3416), value='3'), TableCell(bbox=BBox(x1=6830, y1=3354, x2=6975, y2=3416), value='4'), TableCell(bbox=BBox(x1=6975, y1=3354, x2=7141, y2=3416), value='12'), TableCell(bbox=BBox(x1=7141, y1=3354, x2=7389, y2=3416), value='3.46'), TableCell(bbox=BBox(x1=7389, y1=3354, x2=7636, y2=3416), value=None)]), (5, [TableCell(bbox=BBox(x1=5993, y1=3416, x2=6686, y2=3714), value='Gewicht kg/Stck\nGesamtgewicht 867.135 kg'), TableCell(bbox=BBox(x1=5993, y1=3416, x2=6686, y2=3714), value='Gewicht kg/Stck\nGesamtgewicht 867.135 kg'), TableCell(bbox=BBox(x1=5993, y1=3416, x2=6686, y2=3714), value='Gewicht kg/Stck\nGesamtgewicht 867.135 kg'), TableCel ...
# ExtractedTable(title=None, bbox=(5993, 3103, 7636, 3714),shape=(6, 10))
# OrderedDict([(0, [TableCell(bbox=BBox(x1=7925, y1=3165, x2=8609, y2=3701), value='BETONDECKUNG\n(Längsstab)\n(\nBügel)\nAbstandhalter\nVerlegemaß'), TableCell(bbox=BBox(x1=8609, y1=3165, x2=9011, y2=3701), value='S-Haken\nbei Baustahlgewebe'), TableCell(bbox=BBox(x1=9011, y1=3165, x2=9412, y2=3701), value='- bei Rundstahl\n(senkrechte Stäbe'), TableCell(bbox=BBox(x1=9412, y1=3165, x2=9815, y2=3701), value='bei Rundstahl\n(senkrechte Stäbe innen)')]), (1, [TableCell(bbox=BBox(x1=7925, y1=3701, x2=9815, y2=6960), value='BAUSTOFFE\nBetondeckung\nBeton Festigkeitsklasse\nBetonstahl\nNennmaß (mm)\nFeuchtigkeitsklasse\nBSt\nBSt\n(A\nBauteil\n(A\noben\nWO WF WS\nunten\nBEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstabstahl - Positionen\nD\nnach DIN EN 1992-1-1/NA, Tabelle NA.8.1DEa\nmin\nBetonstahlmatten - Positionen\nAlle Maße und Schnittlängen sind vor der Ausführung zu prüfen\nOBERFLACHEN\nSichtbeton glatt\nEinfüllseite\nSonderstruktur\nAlle\nKanten\nfasen\n3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=3701, x2=9815, y2=6960), value='BAUSTOFFE\nBetondeckung\nBeton Festigkeitsklasse\nBetonstahl\nNennmaß (mm)\nFeuchtigkeitsklasse\nBSt\nBSt\n(A\nBauteil\n(A\noben\nWO WF WS\nunten\nBEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstabstahl - Positionen\nD\nnach DIN EN 1992-1-1/NA, Tabelle NA.8.1DEa\nmin\nBetonstahlmatten - Positionen\nAlle Maße und Schnittlängen sind vor der Ausführung zu prüfen\nOBERFLACHEN\nSichtbeton glatt\nEinfüllseite\nSonderstruktur\nAlle\nKanten\nfasen\n3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=3701, x2=9815, y2=6960), value='BAUSTOFFE\nBetondeckung\nBeton Festigkeitsklasse\nBetonstahl\nNennmaß (mm)\nFeuchtigkeitsklasse\nBSt\nBSt\n(A\nBauteil\n(A\noben\nWO WF WS\nunten\nBEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstabstahl - Positionen\nD\nnach DIN EN 1992-1-1/NA, Tabelle NA.8.1DEa\nmin\nBetonstahlmatten - Positionen\nAlle Maße und Schnittlängen sind vor der Ausführung zu prüfen\nOBERFLACHEN\nSichtbeton glatt\nEinfüllseite\nSonderstruktur\nAlle\nKanten\nfasen\n3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=3701, x2=9815, y2=6960), value='BAUSTOFFE\nBetondeckung\nBeton Festigkeitsklasse\nBetonstahl\nNennmaß (mm)\nFeuchtigkeitsklasse\nBSt\nBSt\n(A\nBauteil\n(A\noben\nWO WF WS\nunten\nBEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstabstahl - Positionen\nD\nnach DIN EN 1992-1-1/NA, Tabelle NA.8.1DEa\nmin\nBetonstahlmatten - Positionen\nAlle Maße und Schnittlängen sind vor der Ausführung zu prüfen\nOBERFLACHEN\nSichtbeton glatt\nEinfüllseite\nSonderstruktur\nAlle\nKanten\nfasen\n3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer A ...
# ExtractedTable(title=None, bbox=(7925, 3165, 9815, 6960),shape=(2, 4))
# OrderedDict([(0, [TableCell(bbox=BBox(x1=7925, y1=3736, x2=8458, y2=4028), value='BAUSTOFFE\nBeton\nBauteil'), TableCell(bbox=BBox(x1=8230, y1=3736, x2=8945, y2=4028), value='Beton Festigkeitsklasse'), TableCell(bbox=BBox(x1=8830, y1=3736, x2=9206, y2=4028), value='Betonstahl\nBSt\nBSt\n(A\n(A'), TableCell(bbox=BBox(x1=8830, y1=3736, x2=9206, y2=4028), value='Betonstahl\nBSt\nBSt\n(A\n(A'), TableCell(bbox=BBox(x1=9206, y1=3736, x2=9525, y2=4028), value='Betondeckung\nNennmaß (mm)\noben\nunten'), TableCell(bbox=BBox(x1=9206, y1=3736, x2=9525, y2=4028), value='Betondeckung\nNennmaß (mm)\noben\nunten'), TableCell(bbox=BBox(x1=9206, y1=3736, x2=9525, y2=4028), value='Betondeckung\nNennmaß (mm)\noben\nunten'), TableCell(bbox=BBox(x1=9525, y1=3736, x2=9815, y2=4028), value='Feuchtigkeitsklasse\nWO WF WS')]), (1, [TableCell(bbox=BBox(x1=7925, y1=4028, x2=9815, y2=6960), value='BEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstabstahl - Positionen\nD\nnach DIN EN 1992-1-1/NA, Tabelle NA.8.1DEa\nmin\nBetonstahlmatten - Positionen\nAlle Maße und Schnittlängen sind vor der Ausführung zu prüfen\nOBERFLACHEN\nSichtbeton glatt\nEinfüllseite\nSonderstruktur\nAlle\nKanten\nfasen\n3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=4028, x2=9815, y2=6960), value='BEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstabstahl - Positionen\nD\nnach DIN EN 1992-1-1/NA, Tabelle NA.8.1DEa\nmin\nBetonstahlmatten - Positionen\nAlle Maße und Schnittlängen sind vor der Ausführung zu prüfen\nOBERFLACHEN\nSichtbeton glatt\nEinfüllseite\nSonderstruktur\nAlle\nKanten\nfasen\n3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=4028, x2=9815, y2=6960), value='BEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstabstahl - Positionen\nD\nnach DIN EN 1992-1-1/NA, Tabelle NA.8.1DEa\nmin\nBetonstahlmatten - Positionen\nAlle Maße und Schnittlängen sind vor der Ausführung zu prüfen\nOBERFLACHEN\nSichtbeton glatt\nEinfüllseite\nSonderstruktur\nAlle\nKanten\nfasen\n3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=4028, x2=9815, y2=6960), value='BEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstabstahl - Positionen\nD\nnach DIN EN 1992-1-1/NA, Tabelle NA.8.1DEa\nmin\nBetonstahlmatten - Positionen\nAlle Maße und Schnittlängen sind vor der Ausführung zu prüfen\nOBERFLACHEN\nSichtbeton glatt\nEinfüllseite\nSonderstruktur\nAlle\nKanten\nfasen\n3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=4028, x2=9815, y2=6960), value='BEWEHRUNG\nBiegemaße gelten von Außenkante zu Außenkante Stahl\nBetonstab ...
# ExtractedTable(title=None, bbox=(7925, 3736, 9815, 6960),shape=(2, 8))
# OrderedDict([(0, [TableCell(bbox=BBox(x1=7925, y1=4933, x2=8348, y2=5119), value='OBERFLACHEN'), TableCell(bbox=BBox(x1=8348, y1=4933, x2=8638, y2=5119), value='Sichtbeton glatt'), TableCell(bbox=BBox(x1=8638, y1=4933, x2=8902, y2=5119), value='Einfüllseite'), TableCell(bbox=BBox(x1=8902, y1=4933, x2=9157, y2=5119), value=None), TableCell(bbox=BBox(x1=9157, y1=4933, x2=9433, y2=5119), value='Sonderstruktur'), TableCell(bbox=BBox(x1=9433, y1=4933, x2=9815, y2=5119), value='Alle\nKanten\nfasen')]), (1, [TableCell(bbox=BBox(x1=7925, y1=5119, x2=9815, y2=6960), value='3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5119, x2=9815, y2=6960), value='3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5119, x2=9815, y2=6960), value='3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5119, x2=9815, y2=6960), value='3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5119, x2=9815, y2=6960), value='3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5119, x2=9815, y2=6960), value='3\n3.97\n9.92\nPrüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status')])])
# ExtractedTable(title=None, bbox=(7925, 4933, 9815, 6960),shape=(2, 6))
# OrderedDict([(0, [TableCell(bbox=BBox(x1=7925, y1=5213, x2=8348, y2=5316), value=None), TableCell(bbox=BBox(x1=8348, y1=5213, x2=8592, y2=5316), value='3'), TableCell(bbox=BBox(x1=8592, y1=5213, x2=8837, y2=5316), value=None), TableCell(bbox=BBox(x1=8837, y1=5213, x2=9081, y2=5316), value=None), TableCell(bbox=BBox(x1=9081, y1=5213, x2=9326, y2=5316), value=None), TableCell(bbox=BBox(x1=9326, y1=5213, x2=9555, y2=5316), value='3.97'), TableCell(bbox=BBox(x1=9555, y1=5213, x2=9815, y2=5316), value='9.92')]), (1, [TableCell(bbox=BBox(x1=7925, y1=5316, x2=9815, y2=6960), value='Prüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5316, x2=9815, y2=6960), value='Prüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5316, x2=9815, y2=6960), value='Prüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5316, x2=9815, y2=6960), value='Prüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5316, x2=9815, y2=6960), value='Prüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5316, x2=9815, y2=6960), value='Prüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5316, x2=9815, y2=6960), value='Prüfingenieur\nAnderung\nKLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status')])])
# ExtractedTable(title=None, bbox=(7925, 5213, 9815, 6960),shape=(2, 7))
# OrderedDict([(0, [TableCell(bbox=BBox(x1=7925, y1=5612, x2=8146, y2=5662), value=None), TableCell(bbox=BBox(x1=8146, y1=5612, x2=8264, y2=5662), value=None), TableCell(bbox=BBox(x1=8264, y1=5612, x2=8382, y2=5662), value=None), TableCell(bbox=BBox(x1=8382, y1=5612, x2=9815, y2=5662), value='Prüfingenieur')]), (1, [TableCell(bbox=BBox(x1=7925, y1=5662, x2=8146, y2=5713), value=None), TableCell(bbox=BBox(x1=8146, y1=5662, x2=8264, y2=5713), value=None), TableCell(bbox=BBox(x1=8264, y1=5662, x2=8382, y2=5713), value=None), TableCell(bbox=BBox(x1=8382, y1=5662, x2=9815, y2=5713), value='Anderung')]), (2, [TableCell(bbox=BBox(x1=7925, y1=5713, x2=9815, y2=6960), value='KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5713, x2=9815, y2=6960), value='KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5713, x2=9815, y2=6960), value='KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status'), TableCell(bbox=BBox(x1=7925, y1=5713, x2=9815, y2=6960), value='KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nMartin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de\nSand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\n819-19\nPos. 09-001\nPlan. Index / Status')])])
# ExtractedTable(title=None, bbox=(7925, 5612, 9815, 6960),shape=(3, 4))
# OrderedDict([(0, [TableCell(bbox=BBox(x1=7925, y1=5764, x2=9815, y2=6035), value='KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2'), TableCell(bbox=BBox(x1=7925, y1=5764, x2=9815, y2=6035), value='KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2'), TableCell(bbox=BBox(x1=7925, y1=5764, x2=9815, y2=6035), value='KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2'), TableCell(bbox=BBox(x1=7925, y1=5764, x2=9815, y2=6035), value='KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2'), TableCell(bbox=BBox(x1=7925, y1=5764, x2=9815, y2=6035), value='KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2')]), (1, [TableCell(bbox=BBox(x1=7925, y1=6035, x2=9815, y2=6415), value='Martin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de'), TableCell(bbox=BBox(x1=7925, y1=6035, x2=9815, y2=6415), value='Martin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de'), TableCell(bbox=BBox(x1=7925, y1=6035, x2=9815, y2=6415), value='Martin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de'), TableCell(bbox=BBox(x1=7925, y1=6035, x2=9815, y2=6415), value='Martin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de'), TableCell(bbox=BBox(x1=7925, y1=6035, x2=9815, y2=6415), value='Martin Schütz GmbH\nPlatenstraße 45\nmartin sc\n91054 Erlangen\nTel. 09131-917 22-10\nplanung im gleichgewicht\nwww.plan-er.de')]), (2, [TableCell(bbox=BBox(x1=7925, y1=6415, x2=8061, y2=6552), value=None), TableCell(bbox=BBox(x1=8061, y1=6415, x2=8289, y2=6552), value=None), TableCell(bbox=BBox(x1=8061, y1=6415, x2=8289, y2=6552), value=None), TableCell(bbox=BBox(x1=8289, y1=6415, x2=9358, y2=6772), value='Sand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\nPos. 09-001'), TableCell(bbox=BBox(x1=9358, y1=6415, x2=9815, y2=6699), value='819-19')]), (3, [TableCell(bbox=BBox(x1=7925, y1=6552, x2=8061, y2=6659), value=None), TableCell(bbox=BBox(x1=8061, y1=6552, x2=8289, y2=6659), value=None), TableCell(bbox=BBox(x1=8061, y1=6552, x2=8289, y2=6659), value=None), TableCell(bbox=BBox(x1=8289, y1=6415, x2=9358, y2=6772), value='Sand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\nPos. 09-001'), TableCell(bbox=BBox(x1=9358, y1=6415, x2=9815, y2=6699), value='819-19')]), (4, [TableCell(bbox=BBox(x1=7925, y1=6659, x2=8061, y2=6772), value=None), TableCell(bbox=BBox(x1=8061, y1=6659, x2=8289, y2=6772), value=None), TableCell(bbox=BBox(x1=8061, y1=6659, x2=8289, y2=6772), value=None), TableCell(bbox=BBox(x1=8289, y1=6415, x2=9358, y2=6772), value='Sand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\nPos. 09-001'), TableCell(bbox=BBox(x1=9358, y1=6415, x2=9815, y2=6699), value='819-19')]), (5, [TableCell(bbox=BBox(x1=7925, y1=6659, x2=8061, y2=6772), value=None), TableCell(bbox=BBox(x1=8061, y1=6659, x2=8289, y2=6772), value=None), TableCell(bbox=BBox(x1=8061, y1=6659, x2=8289, y2=6772), value=None), TableCell(bbox=BBox(x1=8289, y1=6415, x2=9358, y2=6772), value='Sand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\nPos. 09-001'), TableCell(bbox=BBox(x1=9358, y1=6699, x2=9815, y2=6772), value='Plan. Index / Status')])])
# ExtractedTable(title=None, bbox=(7925, 5764, 9815, 6772),shape=(6, 5))

# %%
import fitz  # PyMuPDF
import pandas as pd
import io
from IPython.display import Image as IPythonImage


def show_image(item, title=""):
    """Display a pixmap.

    Just to display Pixmap image of "item" - ignore the man behind the curtain.

    Args:
        item: any PyMuPDF object having a "get_pixmap" method.
        title: a string to be used as image title

    Generates an RGB Pixmap from item using a constant DPI and using matplotlib
    to show it inline of the notebook.
    """
    DPI = 300  # use this resolution
    import numpy as np
    import matplotlib.pyplot as plt

    # %matplotlib inline
    pix = item.get_pixmap(dpi=DPI)
    img = np.ndarray([pix.h, pix.w, 3], dtype=np.uint8, buffer=pix.samples_mv)
    plt.figure(dpi=DPI)  # set the figure's DPI
    plt.title(title)  # set title of image
    _ = plt.imshow(img, extent=(0, pix.w * 72 / DPI, pix.h * 72 / DPI, 0))

def extract_and_display_tables(pdf_path):
    # Open the PDF document
    doc = fitz.open(pdf_path)
    
    # Assuming there's only one page
    page = doc[0]
    
    # Find tables on the page
    tabs = page.find_tables()
    
    for i, tab in enumerate(tabs):  # iterate over all tables
        print(f"Table {i}:")
        
        # Crop the image and save it
        bbox = tab.bbox # get the bounding box of the table
        # maintain aspect ratio
        width = 800
        height = int(width * (bbox[3] - bbox[1]) / (bbox[2] - bbox[0]))
        # save the cropped image
        img = page.get_pixmap(matrix=fitz.Matrix(300/72, 300/72), clip=bbox)
        img.save(f"table_{i}.png")
        
        print(f"Column names: {tab.header.names}, external: {tab.header.external}")
        print("Content:")
        print(tab.extract())
    


# Usage example
pdf_path = "/home/mushtaq96/makersHome/Hackathon/09_Wände/FT_XX_09-001_a_F.pdf"
extract_and_display_tables(pdf_path)
# Out:
# Table 0:
# Column names: ['Pos. Stck Bez', 'eichnung'], external: False
# Content:
# [['Pos. Stck Bez', 'eichnung'], ['1209 2 Kug', 'elkopf-Stabanker 750-7,5to; Zulagebewehrung nach Herstellerangaben'], ['2024 2 Ank', 'erschiene 38/17 L=15cm verzinkt'], ['4062 4 Phil', 'ipp Power Duo-Schiene h=70mm, L=1.25m'], ['5003-20 3 Hüll', 'wellrohr D=50mm L=20cm']]
# Table 1:
# Column names: ['TAB 1. Mindestwerte der Biegerollendurchmesser bei einmaligem Biegen (DIN EN 1992-1-1/NA, Tabelle NA.8.1a)', None, None, None, None], external: False
# Content:
# [['TAB 1. Mindestwerte der Biegerollendurchmesser bei einmaligem Biegen (DIN EN 1992-1-1/NA, Tabelle NA.8.1a)', None, None, None, None], ['D\nmin2 min1\nD\nmin1\nds D', 'Haken, Winkelhaken,\nSchlaufen, Bügel (D )\nmin 1', None, 'Schrägstäbe oder andere\ngebogene Stäbe (D )\nmin 2', None], [None, 'Stabdurchmesser ds', None, 'Mindestwerte der Betondeckung\nrechtwinklig zur Biegeebene', None], [None, '<20mm', '_>20m', '>100mm\nm\n>7 ds', '>50mm _<50mm\n>3 ds _<3 ds'], ['Normalbeton', '4 ds', '7 ds', '10 ds', '15 ds 20 ds'], ['Leichtbeton\nnach DIN EN 1992-1-1, 11.8.11', '6 ds', '10,5 d', 's 15 ds', '22,5 ds 30 ds']]
# Table 2:
# Column names: ['TAB 2. Mindestwerte der Biegerollendurchmesser d für nach dem Schweißen gebogene Bewehrung\nbr\nbei einmaligen Biegen (DIN EN 1992-1-1/NA, Tabelle NA.8.1b)', None, None, None, None], external: False
# Content:
# [['TAB 2. Mindestwerte der Biegerollendurchmesser d für nach dem Schweißen gebogene Bewehrung\nbr\nbei einmaligen Biegen (DIN EN 1992-1-1/NA, Tabelle NA.8.1b)', None, None, None, None], ['>_a\nD\nm\n>a\n_', 'Vorwiegend ruhende Einwirkungen\nds\nin Schweißung außerhalb Schweißung innerhalb\ndes Biegebereiches des Biegebereiches', None, 'Nicht vorwiegend ruhende Einwirkungen', None], [None, None, 'Schweißung innerhalb\ndes Biegebereiches', 'Schweißung auf der\nAußenseite\nder Biegung', 'Schweißung auf der\nInnenseite\nder Biegung'], ['für a <4 ds', '20 ds', '20 ds', '100 ds', '500 ds'], ['für a >_4 ds', 'Werte nach Tabelle\nTAB 1', None, None, None]]
# Table 3:
# Column names: [None, None, None, None, 'B500A', None, None, None, None], external: False
# Content:
# [[None, None, None, None, 'B500A', None, None, None, None], ['Anz.', 'Bez/Typ', 'Breite', 'Länge', 'Pos.', 'Anz.', 'ø', 'Länge', 'Bem.:'], ['8', 'R188A', '2.30', '1.00', '1', '2', '20', '0.35', ''], ['6\n2', 'Q335A\nQ335A', '2.30\n0.85', '2.93\n2.93', '2\n3', '4\n4', '12\n12', '6.46\n3.46', ''], [None, None, None, None, 'Gewicht 3*36.965 kg/Stck.\nGesamtgewicht 110.895 kg', None, None, None, None]]
# Table 4:
# Column names: ['BETONDECKUNG S-Ha\n- bei\nu\ns c V\nVerlegemaß\nd (Längsstab)\nsl\nd (Bügel)\nsbü\nAbstandhalter\nVerlegemaß c c', 'ken - bei\nBaustahlgewebe ( s en\nc', 'Rundstahl\nkrechte S täbe a ußen):\nc c\nVS VS\nc c', '- bei Rundstahl\n( s enkrechte S täbe i n nen):\nc c\nVS VS\nc c'], external: False
# Content:
# [['BETONDECKUNG S-Ha\n- bei\nu\ns c V\nVerlegemaß\nd (Längsstab)\nsl\nd (Bügel)\nsbü\nAbstandhalter\nVerlegemaß c c', 'ken - bei\nBaustahlgewebe ( s en\nc', 'Rundstahl\nkrechte S täbe a ußen):\nc c\nVS VS\nc c', '- bei Rundstahl\n( s enkrechte S täbe i n nen):\nc c\nVS VS\nc c'], [None, '', None, None]]
# Table 5:
# Column names: ['10', '', ''], external: True
# Content:
# [['', None, ''], [None, '10', None]]
# Table 6:
# Column names: ['. .', 'X . . . .', '. .', 'X', 'X 25 25', '25 X . . .'], external: False
# Content:
# [['. .', 'X . . . .', '. .', 'X', 'X 25 25', '25 X . . .'], ['. .', '. . . . .', '. .', '.', '. . .', '. . . . .'], ['. .', '. . . . .', '. .', '.', '. . .', '. . . . .']]
# Table 7:
# Column names: ['unbewehrt', 'Bewehrungskorrosion\nChloride Chloride\nKarbonatisierung\n(o. Mee rwasser) (a. Me erwasser) (', None, None, 'Betonangriff', None], external: False
# Content:
# [['unbewehrt', 'Bewehrungskorrosion\nChloride Chloride\nKarbonatisierung\n(o. Mee rwasser) (a. Me erwasser) (', None, None, 'Betonangriff', None], [None, None, 'ide Chloride\nasser) (a. Me erwasser) (', None, 'Frost\nche\nmit/ohne Ta umittel)', 'm. Angriff Verschleiß'], ['Expositionsklasse X0', 'XC1 XC2 XC3 XC4 XD1 XD', '2 XD3 XS1', 'XS2 XS3 XF', '1 XF2 XF3 XF4 XA1', 'XA2 XA3 XM1 XM2 XM3'], ['. .', 'X . . . . .', '. .', '. . .', '. . . .', '. . . . .'], ['. .', '. . . . . .', '. .', '. . .', '. . . .', '. . . . .'], ['. .', '. . . . . .', '. .', '. . .', '. . . .', '. . . . .']]
# Table 8:
# Column names: ['Fertigteil - Position', 'Stück Läng', 'e Breite', 'Höhe Volum', 'en (m3) Gewicht (to.)'], external: False
# Content:
# [['Fertigteil - Position', 'Stück Läng', 'e Breite', 'Höhe Volum', 'en (m3) Gewicht (to.)'], ['09-001', '3 6.6', '6 2.98', '0.20 3', '.97 9.92']]
# Table 9:
# Column names: ['. f', '. .'], external: False
# Content:
# [['. f', '. .'], ['. e', '. .'], ['. d\n. c', '. .\n. .'], ['. b', '. .'], ['28.01.2020 a', 'AH Prüffreigabe Prüfingenieur'], ['Datum Index', 'Name Änderung']]
# Table 10:
# Column names: ['KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nTel. (0 91 81) 9 00-0', None, None], external: False
# Content:
# [['KLEBL GmbH\n92318 Neumarkt i. d. OPf. Gößweinstraße 2\nTel. (0 91 81) 9 00-0', None, None], ['', None, None], ['Datum 21.11.2019', 'B a u v o r h a b e n / B a u t e i l', 'Auftr. Nr'], ['Gez. Hübner', 'Sand- und Baustoffwerke Neumarkt GmbH & Co.KG\nNeubau einer Ausstellungshalle, und Containerhalle mit Büro\nWandplatte Pos. 09-001', '819-19'], ['stat.Pos -', None, None], ['Maßstab 1:25', None, None], [None, None, 'Plan. Nr / Index / Status'], ['Planschlüssel', 'FT_XX_09-001_a_F', None]]

# %%
# choose the second table for conversion to a DataFrame
tab = tabs[1]
df = tab.to_pandas()

# show the DataFrame
df
